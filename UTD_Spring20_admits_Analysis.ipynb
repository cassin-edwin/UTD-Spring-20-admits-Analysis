# %%
import tabula

# %%
import pandas as pd
import numpy as np

# %%
df  = tabula.read_pdf("C:/Users/Cassin/Desktop/Contact Information (Responses).pdf", set_index = "Name")

# %%
df
# Out:
#              Timestamp                     Name                     Email  \
# 0   11/3/2019 19:01:12               Sahil Shah     sahil14dec91@gmail.co
# 1   11/3/2019 19:15:00   Sirija Reddy Saimadugu       sirijas95@gmail.com
# 2   11/3/2019 19:15:21        Sai Meghana Reddy       meghanareddy1296@gm
# 3   11/3/2019 19:31:47               Sahil Shah     sahil14dec91@gmail.co
# 4   11/3/2019 19:37:25          Sakruth Puskuri        psakruth@gmail.com
# 5   11/3/2019 19:37:43                 Bhargava      bhargava.machineni@g
# 6   11/3/2019 19:38:11              Divya Mehta      divya.mehta240293@gm
# 7   11/3/2019 19:38:34                Madhuri K      madhuriemmekar@gmail
# 8   11/3/2019 19:38:46             Varun Samant       vsamant94@gmail.com
# 9   11/3/2019 19:39:09          Sanjana Vuyyuru    vuyyurusanjana8@gmail.
# 10  11/3/2019 19:45:41          Gorish Kasliwal     gorish.jain@gmail.com
# 11  11/3/2019 19:47:06                    Kavya    kavyaravulapati96@gmai
# ...

# %%
df.rename(columns = { df.columns[14]: "Cooking\"}, inplace = True)

# %%
df['Roommates preferred'].unique()
# Out:
# array(['No', 'Male', 'Both', 'Female'], dtype=object)

# %%
df1 = df
df1.head()
# Out:
#             Timestamp                    Name                  Email  \
# 0  11/3/2019 19:01:12              Sahil Shah  sahil14dec91@gmail.co
# 1  11/3/2019 19:15:00  Sirija Reddy Saimadugu    sirijas95@gmail.com
# 2  11/3/2019 19:15:21       Sai Meghana Reddy    meghanareddy1296@gm
# 3  11/3/2019 19:31:47              Sahil Shah  sahil14dec91@gmail.co
# 4  11/3/2019 19:37:25         Sakruth Puskuri     psakruth@gmail.com
#
#        Phone number Where are you from?  Gender Admission Decision  \
# 0       09870670773              Mumbai    Male           Admitted
# 1                No           Hyderabad  Female           Admitted
# 2  il.com8985997600           Hyderabad  Female           Admitted
# 3       09870670773              Mumbai    Male           Admitted
# 4        9573719189           Hyderabad    Male           Admitted
#
#   Will you be joining UTD?        Which major?    Housing?       Visa Status  \
# ...

# %%
df.replace(to_replace = 'Amatuer', value = 'Amateur', inplace = True)

# %%
df["Housing?"].fillna("Undecided", inplace = True)

# %%
df['Roommates preferred'].replace('gFliesmhale','Female', inplace = True)

# %%
df.iloc[33,15] = 'English,Hindi'

# %%
df['Languages known'].unique()
# Out:
# array(['English, Hindi, Gujarati, Kutchi', 'English,Telugu,Hindi',
#        'English,Telugu', 'English,Hindi', 'English,Hindi,Marathi',
#        'English,Telegu,Hindi', 'Not Mentioned',
#        'English,Telegu,Hindi,Tamil', 'English, Assamese, Hindi',
#        'English, Tamil', 'English, Gujarati, Hindi',
#        'English,Hindi,Gujarati', 'English,Hindi,Telegu,Tamil',
#        'English,Hindi,Telegu,Marathi'], dtype=object)

# %%
df.head(5)
# Out:
#             Timestamp                    Name                  Email  \
# 0  11/3/2019 19:01:12              Sahil Shah  sahil14dec91@gmail.co
# 1  11/3/2019 19:15:00  Sirija Reddy Saimadugu    sirijas95@gmail.com
# 2  11/3/2019 19:15:21       Sai Meghana Reddy    meghanareddy1296@gm
# 3  11/3/2019 19:31:47              Sahil Shah  sahil14dec91@gmail.co
# 4  11/3/2019 19:37:25         Sakruth Puskuri     psakruth@gmail.com
#
#        Phone number Where are you from?  Gender Admission Decision  \
# 0       09870670773              Mumbai    Male           Admitted
# 1                No           Hyderabad  Female           Admitted
# 2  il.com8985997600           Hyderabad  Female           Admitted
# 3       09870670773              Mumbai    Male           Admitted
# 4        9573719189           Hyderabad    Male           Admitted
#
#   Will you be joining UTD?        Which major?    Housing?       Visa Status  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize =(17,10))
sns.countplot(x  = 'Where are you from?',data = df1)
plt.ylabel('Count of the student coming from these cities')
plt.title('Comparision of the students coming from various cities',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Comparision of the students coming from various cities')

# %%
df[['First_Lang','Second_Lang','Third_Lang','Fourth_Lang']] = df['Languages known'].str.split(",",expand = True)

# %%
df1.head()
# Out:
#             Timestamp  Name                  Email      Phone number  \
# 0  11/3/2019 19:01:12  None  sahil14dec91@gmail.co       09870670773
# 1  11/3/2019 19:15:00  None    sirijas95@gmail.com                No
# 2  11/3/2019 19:15:21  None    meghanareddy1296@gm  il.com8985997600
# 3  11/3/2019 19:31:47  None  sahil14dec91@gmail.co       09870670773
# 4  11/3/2019 19:37:25  None     psakruth@gmail.com        9573719189
#
#   Where are you from?  Gender Admission Decision Will you be joining UTD?  \
# 0              Mumbai    Male           Admitted                      Yes
# 1           Hyderabad  Female           Admitted                      Yes
# 2           Hyderabad  Female           Admitted                      Yes
# 3              Mumbai    Male           Admitted                      Yes
# 4           Hyderabad    Male           Admitted                      Yes
#
#          Which major?    Housing?  ...  Roomate_Smoking/Drinking  \
# ...

# %%
sns.countplot(data = df1, x = 'Gender')

# %%
plt.figure(figsize = (17,10))
sns.countplot(x = 'Which major?', data = df1)

# %%
df1.dtypes
# Out:
# Timestamp                   object
# Name                        object
# Email                       object
# Phone number                object
# Where are you from?         object
# Gender                      object
# Admission Decision          object
# Will you be joining UTD?    object
# Which major?                object
# Housing?                    object
# Visa Status                 object
# Do you drink/smoke?         object
# Roomate_Smoking/Drinking    object
# Veg/Non-Veg/Egg             object
# Cooking                     object
# Languages known             object
# Roommates preferred         object
# Third_Lang                  object
# First_Lang                  object
# Second_Lang                 object
# Fourth_Lang                 object
# ID                          object
# dtype: object

# %%
count = df1['Languages known'].str.split().apply(len).value_counts()

# %%
count
# Out:
# 1    28
# 4     2
# 3     2
# 2     2
# Name: Languages known, dtype: int64

# %%
df['Number of Languages known'] = count

# %%
df.drop(columns  = 'Number of Languages known', inplace = True)

# %%
df
# Out:
#              Timestamp                     Name                     Email  \
# 0   11/3/2019 19:01:12               Sahil Shah     sahil14dec91@gmail.co
# 1   11/3/2019 19:15:00   Sirija Reddy Saimadugu       sirijas95@gmail.com
# 2   11/3/2019 19:15:21        Sai Meghana Reddy       meghanareddy1296@gm
# 3   11/3/2019 19:31:47               Sahil Shah     sahil14dec91@gmail.co
# 4   11/3/2019 19:37:25          Sakruth Puskuri        psakruth@gmail.com
# 5   11/3/2019 19:37:43                 Bhargava      bhargava.machineni@g
# 6   11/3/2019 19:38:11              Divya Mehta      divya.mehta240293@gm
# 7   11/3/2019 19:38:34                Madhuri K      madhuriemmekar@gmail
# 8   11/3/2019 19:38:46             Varun Samant       vsamant94@gmail.com
# 9   11/3/2019 19:39:09          Sanjana Vuyyuru    vuyyurusanjana8@gmail.
# 10  11/3/2019 19:45:41          Gorish Kasliwal     gorish.jain@gmail.com
# 11  11/3/2019 19:47:06                    Kavya    kavyaravulapati96@gmai
# ...

# %%
sns.countplot(x = 'Do you drink/smoke?', data = df1, hue = 'Gender')

# %%
sns.countplot(x = 'Cooking', data = df1)

# %%
sns.countplot(x = 'Roommates preferred', data = df1, hue = 'Gender')
plt.xlabel('Roomates Preference',fontsize = 16)
# Out:
# Text(0.5, 0, 'Roomates Preference')

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
def fun(df3):
    for i in range(100,100+df1['Name'].count()):
        return (i+1)

# %%
fun()
# Out:
# 1

# %%
df1.head()
# Out:
#             Timestamp  Name                  Email      Phone number  \
# 0  11/3/2019 19:01:12  None  sahil14dec91@gmail.co       09870670773
# 1  11/3/2019 19:15:00  None    sirijas95@gmail.com                No
# 2  11/3/2019 19:15:21  None    meghanareddy1296@gm  il.com8985997600
# 3  11/3/2019 19:31:47  None  sahil14dec91@gmail.co       09870670773
# 4  11/3/2019 19:37:25  None     psakruth@gmail.com        9573719189
#
#   Where are you from?  Gender Admission Decision Will you be joining UTD?  \
# 0              Mumbai    Male           Admitted                      Yes
# 1           Hyderabad  Female           Admitted                      Yes
# 2           Hyderabad  Female           Admitted                      Yes
# 3              Mumbai    Male           Admitted                      Yes
# 4           Hyderabad    Male           Admitted                      Yes
#
#          Which major?    Housing?  ...  Roomate_Smoking/Drinking  \
# ...

# %%
df1.drop('Id', axis =1, inplace = True)

# %%
df1.head()
# Out:
#             Timestamp  Name                  Email      Phone number  \
# 0  11/3/2019 19:01:12  None  sahil14dec91@gmail.co       09870670773
# 1  11/3/2019 19:15:00  None    sirijas95@gmail.com                No
# 2  11/3/2019 19:15:21  None    meghanareddy1296@gm  il.com8985997600
# 3  11/3/2019 19:31:47  None  sahil14dec91@gmail.co       09870670773
# 4  11/3/2019 19:37:25  None     psakruth@gmail.com        9573719189
#
#   Where are you from?  Gender Admission Decision Will you be joining UTD?  \
# 0              Mumbai    Male           Admitted                      Yes
# 1           Hyderabad  Female           Admitted                      Yes
# 2           Hyderabad  Female           Admitted                      Yes
# 3              Mumbai    Male           Admitted                      Yes
# 4           Hyderabad    Male           Admitted                      Yes
#
#          Which major?    Housing?  ...  Roomate_Smoking/Drinking  \
# ...

# %%
def fun(df3):
    for i in range(0,df1['Timestamp'].count()):
        df1['ID'] = i+1

# %%
fun(df1)

# %%
df1['ID'] = range(100,100+df1['Timestamp'].count())

# %%
df1.drop('Name', axis =1, inplace = True)

# %%
df1.head()
# Out:
#             Timestamp                  Email      Phone number  \
# 0  11/3/2019 19:01:12  sahil14dec91@gmail.co       09870670773
# 1  11/3/2019 19:15:00    sirijas95@gmail.com                No
# 2  11/3/2019 19:15:21    meghanareddy1296@gm  il.com8985997600
# 3  11/3/2019 19:31:47  sahil14dec91@gmail.co       09870670773
# 4  11/3/2019 19:37:25     psakruth@gmail.com        9573719189
#
#   Where are you from?  Gender Admission Decision Will you be joining UTD?  \
# 0              Mumbai    Male           Admitted                      Yes
# 1           Hyderabad  Female           Admitted                      Yes
# 2           Hyderabad  Female           Admitted                      Yes
# 3              Mumbai    Male           Admitted                      Yes
# 4           Hyderabad    Male           Admitted                      Yes
#
#          Which major?    Housing?       Visa Status ...   \
# 0  Business Analytics  OFF-CAMPUS    Not yet booked ...
# ...

# %%
df1.drop(columns = ['Timestamp','Email','Phone number'],axis =1, inplace = True)

# %%
df1.head()
# Out:
#   Where are you from?  Gender Admission Decision Will you be joining UTD?  \
# 0              Mumbai    Male           Admitted                      Yes
# 1           Hyderabad  Female           Admitted                      Yes
# 2           Hyderabad  Female           Admitted                      Yes
# 3              Mumbai    Male           Admitted                      Yes
# 4           Hyderabad    Male           Admitted                      Yes
#
#          Which major?    Housing?       Visa Status Do you drink/smoke?  \
# 0  Business Analytics  OFF-CAMPUS    Not yet booked               Drink
# 1  Business Analytics  OFF-CAMPUS        In process                  No
# 2    Computer Science  OFF-CAMPUS        In process                  No
# 3  Business Analytics  OFF-CAMPUS  Waiting for I-20               Drink
# 4  Business Analytics  OFF-CAMPUS        In process                  No
#
#   Roomate_Smoking/Drinking Veg/Non-Veg/Egg  Cooking  \
# ...

# %%
df1.drop(columns = ['Admission Decision','Will you be joining UTD?'], axis =1, inplace = True)

# %%
df1['Third_Lang'] = labelencoder.fit_transform(df1['Third_Lang'])

# %%
df1.head()
# Out:
#    Where are you from?  Gender  Which major?  Housing?  Visa Status  \
# 0                    8       1             0         0            2
# 1                    7       0             0         0            1
# 2                    7       0             1         0            1
# 3                    8       1             0         0            3
# 4                    7       1             0         0            1
#
#    Do you drink/smoke?  Roomate_Smoking/Drinking  Veg/Non-Veg/Egg  Cooking  \
# 0                    1                         2                3        1
# 1                    2                         0                2        2
# 2                    2                         2                2        0
# 3                    1                         2                0        0
# 4                    2                         0                2        1
#
#                     Languages known Roommates preferred Third_Lang  \
# ...

# %%
df1.Third_Lang.unique()
# Out:
# array([' Gujarati', 'Hindi', 'Telegu', 'Marathi', ' Hindi', 'Gujarati'],
#       dtype=object)

# %%
df1['Third_Lang'].replace("Don't Know","Telegu",inplace = True)

# %%
df1.head()
# Out:
#    Where are you from?  Gender  Which major?  Housing?  Visa Status  \
# 0                    8       1             0         0            2
# 1                    7       0             0         0            1
# 2                    7       0             1         0            1
# 3                    8       1             0         0            3
# 4                    7       1             0         0            1
#
#    Do you drink/smoke?  Roomate_Smoking/Drinking  Veg/Non-Veg/Egg  Cooking  \
# 0                    1                         2                3        1
# 1                    2                         0                2        2
# 2                    2                         2                2        0
# 3                    1                         2                0        0
# 4                    2                         0                2        1
#
#   Roommates preferred  Third_Lang  First_Lang  Second_Lang   ID
# ...

# %%
df1.
